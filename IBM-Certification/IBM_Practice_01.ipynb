# %% [markdown]
# What is Machine Learning ?
#
# Machine Learning is the subfield of computer science that gives "computers the ability to learn without being explicitly programmed."
#
# Examples:
# 1. Recommendation.
# 2. Decision Making
# 3. Telecommunication customer segmentation etc
#
# Major machine Learning Techiniques:
# 1. Regression/Estimation
#    -> Predicting continuous values, eg->house price prediction,CO2 Emition Pred
# 2. Classification
#    -> Predicting the item class/category of a case
# 3. Clustering
#    -> Finding the structure of data; summarization
# 4. Associations
#    -> Associating frequent co-occuring items/events
#
# ---------------Techniques-----------
# 1. Anomaly detection
#    -> Discovering abnormal and unusal cases
# 2. Sequence Mining
#    -> Predicting next events; click-strem(Markov Model, HMM)
# 3. Dimension Reduction
#    -> Reducing the size of data(PCA)
# 4. Recommendation Systems
#    -> Recommendation items

# %% [markdown]
# Difference between artificial intelligence, meachine learning, and deep learning
#
# 1. AI Components:
#    -> computer Vision
#    -> Language Processing
#    -> Creativity
#    -> etc.
# 2. Machine Learning:
#    -> Classification
#    -> Clustering
#    -> Neural Network
#    -> etc
# 3. Revolution in ML:
#    -> Deep Learning

# %% [markdown]
# Python Libraries for machine learning
# 1. NUmpy
# 2. SciPy
# 3. Matplotlib
# 4. Pandas
# 5. Scikit Learn

# %% [markdown]
# More about Sk-Learn:
# -> Free Software machine learning Library
# -> Classification, Regression and Clustering Algorithms
# -> Works with Numpy and Scipy
# -> Great Documentation
# -> Easy Implementation
#
#
# Alredy Implemented in Sk-Learn:-
# Data Preprocessing --> Train/Test Split --> Algorithm Setup --> Model Fitting --> Prediction --> Evaluation --> Nodel export.

# %% [markdown]
# Supervised Learning VS Unsupervised Learning:-
#
# 1. Supervised Learning:
#
# We "Teach the model," then with that Knowledge it can predict unknown or   future instances.LABELED DATA is used for Teaching.
#
# 2. Unsupervised Learning:
#
# The model works on its own to discover information.

# %% [markdown]
# What is Classification ?
#
# Classification is the process of predictng discrete class labels or categories.
#
# What is Regression ?
# Regression is the process of predicting continuous values.
